# %%
# %load_ext autoreload
# %autoreload 2


import matplotlib.pyplot as plt
print(plt.style.available)
plt.style.use('classic')
import numpy as np
import torch
import torch.nn as nn

import sys

sys.path.append('../')

# from algorithms.sequence_models.old_decision_transformer.decision_transformer.decision_transformer import DecisionTransformer
from algorithms.sequence_models.decision_transformer.decision_transformer import DecisionTransformer
from algorithms.sequence_models.evaluate import evaluate_on_env
from data.umbrella_length_dataset import UmbrellaLengthDataset
from envs.umbrella_length import get_umbrella_length_env
from data.trajectory import LimitedContextWrapper
from algorithms.sequence_models.config import TrainConfig
from algorithms.sequence_models.decision_transformer.trainer import TrainerDT

from bsuite.experiments import summary_analysis
# from bsuite.logging import csv_load
from bsuite.experiments.umbrella_length import analysis as umbrella_length_analysis
from bsuite import load_and_record_to_csv

from bsuite.utils import gym_wrapper

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']
# pygame 2.5.2 (SDL 2.28.2, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# device(type='cuda')

# %%
class CustomCallback:
	def __init__(self, env, model, optimizer, logger, device, traj_dataset, config, rtgs=[]):
		self.env = env
		self.model = model
		self.optimizer = optimizer
		self.logger = logger
		self.device = device
		self.traj_dataset = traj_dataset
		self.config = config
		self.rtgs = rtgs
		self.eval_results = []
		
	def callback(self, df, **kwargs):
		results = evaluate_on_env(
			model=self.model, traj_dataset=self.traj_dataset,
			device=self.device, context_len=self.config.context_len,
			env=self.env, rtg_target=self.config.rtg_main,
			num_eval_ep=self.config.num_eval_ep,
			max_test_ep_len=self.config.max_eval_ep_len)
		self.logger.log(
				   model=self.model,
				   loss=df['train/loss'].sum(),
				   eval_avg_reward=results['eval/avg_reward'],
				   eval_avg_ep_len=results['eval/avg_ep_len'],
				   grad_norm=max(torch.norm(param.grad) for param in self.model.parameters() if param.grad is not None),
				   lr=self.optimizer.param_groups[0]['lr'],
				   important={"grad_norm", "lr"})
		res = {}
		for rtg in self.rtgs:
			res[rtg] = evaluate_on_env(
				model=self.model,
				traj_dataset=self.traj_dataset,
				device=self.device,
				context_len=self.config.context_len,
				env=self.env,
				rtg_target=rtg,
				num_eval_ep=self.config.num_eval_ep
			)
		self.eval_results.append(res)
	
	def plot_eval_results(self):
		plt.figure()
		for rtg in self.rtgs:
			plt.plot([res[rtg]['eval/avg_reward'] for res in self.eval_results])
		plt.xlabel('iteration')
		plt.ylabel('avg_reward')
		plt.legend([f'r={rtg:.2f}' for rtg in self.rtgs])

		plt.figure()
		
		for rtg in self.rtgs:
			n = len(self.eval_results)
			plt.plot(range(n//2, n), [res[rtg]['eval/avg_reward'] for res in self.eval_results[n//2:]])
			
		plt.xlabel('iteration')
		plt.ylabel('avg_reward')
		plt.legend([f'r={rtg:.2f}' for rtg in self.rtgs])

# %%
env = load_and_record_to_csv('umbrella_length/0', results_dir='/logs/bsuite')
gym_env = gym_wrapper.GymFromDMEnv(env)
reset = env.reset
env.reset = lambda: (reset, {})
print(env.observation_spec())
# env = get_umbrella_length_env(chain_length=4)
obs, info = env.reset()
print(obs)
# plt.imshow(obs)

# todo is this number of trajectories enough?
# todo should the reward scale be 1?
# todo make sure max_steps is not too much. we don't want the context length to be too big
traj_dataset = UmbrellaLengthDataset(env, n_trajectories=200000, reward_scale=1)
# Out:
# Loaded bsuite_id: umbrella_length/0.
# Logging results to CSV file for each bsuite_id in /logs/bsuite.
# Array(shape=(1, 23), dtype=dtype('float32'), name=None)
# <bound method Logging.reset of <bsuite.utils.wrappers.Logging object at 0x7faa30623f40>>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 14
#       8 print(obs)
#       9 # plt.imshow(obs)
#      10
#      11 # todo is this number of trajectories enough?
#      12 # todo should the reward scale be 1?
#      13 # todo make sure max_steps is not too much. we don't want the context length to be too big
# ---> 14 traj_dataset = UmbrellaLengthDataset(env, n_trajectories=200000, reward_scale=1)
#
# File ~/6.8200/RL-credit-assignment-experiment/experiment_notebooks/../data/umbrella_length_dataset.py:18, in UmbrellaLengthDataset.__init__(self, env, n_trajectories, reward_scale)
#      15 super().__init__(gamma=1)
#      17 self.env = env
# ---> 18 policy = RandomPolicy(env)
#      19 self.trajectories = []
#      20 self.trajectories += self.collect_trajectories(self.env, policy, n_trajectories=n_trajectories)
#
# File ~/6.8200/RL-credit-assignment-experiment/experiment_notebooks/../algorithms/random_policy.py:20, in RandomPolicy.__init__(self, env)
#      19 def __init__(self, env: gym.Env):
# ---> 20     self.ob_space = env.observation_space
#      21     self.ac_space = env.action_space
#
# File ~/venvs/sensorimotor/hw3/lib/python3.10/site-packages/bsuite/utils/wrappers.py:138, in Logging.__getattr__(self, attr)
#     136 def __getattr__(self, attr):
#     137   """Delegate attribute access to underlying environment."""
# --> 138   return getattr(self._env, attr)
#
# AttributeError: 'UmbrellaChain' object has no attribute 'observation_space'

# %%
ds_rewards = np.array([traj_dataset.reward_convertor.from_feature_space(traj.returns[0]) for traj in traj_dataset])
# ds_pos_rewards = np.array([ret for ret in ds_rewards if ret > 0])
plt.hist(ds_rewards)
# Out:
# (array([12499.,     0., 49838.,     0.,     0., 75205.,     0., 49980.,
#             0., 12478.]),
#  array([-4. , -3.2, -2.4, -1.6, -0.8,  0. ,  0.8,  1.6,  2.4,  3.2,  4. ]),
#  <BarContainer object of 10 artists>)

# %%
# todo rtg_range_check and rtg_main are used for plotting and monitoring
# todo is the rtg_range_check correct?
config = TrainConfig(max_eval_ep_len=20, context_len=10, rtg_range_check=(-4, 4), rtg_main=5, max_train_iters=300)

experiment_name = 'umbrella-length-experiment'

model = DecisionTransformer(
			state_dim=traj_dataset.state_dim(),
			act_dim=traj_dataset.action_dim(),
			n_blocks=config.n_blocks,
			h_dim=config.embed_dim,
			context_len=config.context_len,
			n_heads=config.n_heads,
			drop_p=config.dropout_p,
).to(device)

optimizer = torch.optim.AdamW(model.parameters(), lr=config.lr, weight_decay=config.wt_decay)

scheduler = torch.optim.lr_scheduler.LambdaLR(
	optimizer,
	lambda steps: min((steps+1)/config.warmup_steps, 1)
)

loss_fn = nn.MSELoss(reduction='mean')

trainer = TrainerDT(name=experiment_name, model=model,
					optimizer=optimizer, loss_fn=loss_fn,
					dataset=LimitedContextWrapper(traj_dataset, context_len=config.context_len),
					device=device, config=config, scheduler=scheduler)

callback = CustomCallback(env=env, model=model,
						  optimizer=optimizer, logger=trainer.logger, device=device, traj_dataset=traj_dataset, config=config,
						  rtgs=[-4, 4])

trainer.register_callback(callback.callback)

print("number of parameters", sum(np.prod(param.shape) for param in model.parameters()))
# Out:
# number of parameters 1126426

# %%
report = trainer.train()
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# achieved average reward:  0.6
# saving max score model at: /home/muhender/6.8200/RL-credit-assignment-experiment/logs/dt_runs/dt_umbrella-length-experiment_model_24-05-10-22-23-06_best.pt
# ============================================================
# time elapsed: 0:00:02
# num of updates: 100
# loss: 30.55079
# eval avg reward: 0.60000
# best score: -inf
# eval_avg_ep_len 4.00000
# grad_norm 0.17726
# lr 0.00001
# achieved average reward:  0.6
# saving max score model at: /home/muhender/6.8200/RL-credit-assignment-experiment/logs/dt_runs/dt_umbrella-length-experiment_model_24-05-10-22-23-06_best.pt
# ============================================================
# time elapsed: 0:00:04
# num of updates: 200
# loss: 26.52320
# eval avg reward: 0.60000
# best score: 0.60000
# eval_avg_ep_len 4.00000
# grad_norm 0.17455
# lr 0.00002
# ============================================================
# time elapsed: 0:00:06
# num of updates: 300
# loss: 25.92202
# eval avg reward: -0.40000
# best score: 0.60000
# eval_avg_ep_len 4.00000
# grad_norm 0.18374
# lr 0.00003
# ============================================================
# time elapsed: 0:00:08
# num of updates: 400
# loss: 25.76432
# eval avg reward: -0.40000
# best score: 0.60000
# eval_avg_ep_len 4.00000
# grad_norm 0.18506
# lr 0.00004
# ============================================================
# time elapsed: 0:00:11
# num of updates: 500
# loss: 25.51386
# eval avg reward: -1.40000
# best score: 0.60000
# eval_avg_ep_len 4.00000
# grad_norm 0.20206
# lr 0.00005
# ============================================================
# time elapsed: 0:00:13
# num of updates: 600
# loss: 25.46358
# eval avg reward: -0.20000
# best score: 0.60000
# eval_avg_ep_len 4.00000
# grad_norm 0.19573
# lr 0.00006
# ============================================================
# time elapsed: 0:00:15
# num of updates: 700
# loss: 25.25932
# eval avg reward: 0.40000
# best score: 0.60000
# eval_avg_ep_len 4.00000
# grad_norm 0.20452
# lr 0.00007
# achieved average reward:  1.2
# saving max score model at: /home/muhender/6.8200/RL-credit-assignment-experiment/logs/dt_runs/dt_umbrella-length-experiment_model_24-05-10-22-23-06_best.pt
# ============================================================
# time elapsed: 0:00:18
# num of updates: 800
# loss: 25.09172
# eval avg reward: 1.20000
# best score: 0.60000
# eval_avg_ep_len 4.00000
# grad_norm 0.20571
# lr 0.00008
# achieved average reward:  1.2
# saving max score model at: /home/muhender/6.8200/RL-credit-assignment-experiment/logs/dt_runs/dt_umbrella-length-experiment_model_24-05-10-22-23-06_best.pt
# ============================================================
# time elapsed: 0:00:20
# num of updates: 900
# loss: 24.45917
# eval avg reward: 1.20000
# best score: 1.20000
# eval_avg_ep_len 4.00000
# grad_norm 0.20157
# lr 0.00009
# ============================================================
# time elapsed: 0:00:22
# num of updates: 1000
# loss: 24.00257
# eval avg reward: 1.00000
# best score: 1.20000
# eval_avg_ep_len 4.00000
# grad_norm 0.19939
# lr 0.00010
# ============================================================
# time elapsed: 0:00:24
# num of updates: 1100
# loss: 23.91665
# eval avg reward: 0.80000
# best score: 1.20000
# eval_avg_ep_len 4.00000
# grad_norm 0.21869
# lr 0.00011
# achieved average reward:  1.8
# saving max score model at: /home/muhender/6.8200/RL-credit-assignment-experiment/logs/dt_runs/dt_umbrella-length-experiment_model_24-05-10-22-23-06_best.pt
# ============================================================
# time elapsed: 0:00:26
# num of updates: 1200
# loss: 23.85355
# eval avg reward: 1.80000
# best score: 1.20000
# eval_avg_ep_len 4.00000
# grad_norm 0.22176
# lr 0.00012
# ============================================================
# time elapsed: 0:00:29
# num of updates: 1300
# loss: 23.89051
# eval avg reward: 1.00000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.22376
# lr 0.00013
# ============================================================
# time elapsed: 0:00:31
# num of updates: 1400
# loss: 23.85897
# eval avg reward: 1.20000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.22898
# lr 0.00014
# ============================================================
# time elapsed: 0:00:34
# num of updates: 1500
# loss: 23.71487
# eval avg reward: 0.20000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.23047
# lr 0.00015
# ============================================================
# time elapsed: 0:00:36
# num of updates: 1600
# loss: 23.62919
# eval avg reward: 0.80000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.23246
# lr 0.00016
# ============================================================
# time elapsed: 0:00:38
# num of updates: 1700
# loss: 23.84022
# eval avg reward: 1.40000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.23593
# lr 0.00017
# ============================================================
# time elapsed: 0:00:41
# num of updates: 1800
# loss: 23.66251
# eval avg reward: 0.80000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.23434
# lr 0.00018
# ============================================================
# time elapsed: 0:00:43
# num of updates: 1900
# loss: 23.61499
# eval avg reward: 1.20000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.23191
# lr 0.00019
# ============================================================
# time elapsed: 0:00:45
# num of updates: 2000
# loss: 23.65424
# eval avg reward: -0.20000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.23458
# lr 0.00020
# ============================================================
# time elapsed: 0:00:47
# num of updates: 2100
# loss: 23.61524
# eval avg reward: 0.60000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.23965
# lr 0.00021
# ============================================================
# time elapsed: 0:00:49
# num of updates: 2200
# loss: 23.66205
# eval avg reward: 1.00000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.24074
# lr 0.00022
# ============================================================
# time elapsed: 0:00:51
# num of updates: 2300
# loss: 23.73561
# eval avg reward: 0.20000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.15479
# lr 0.00023
# ============================================================
# time elapsed: 0:00:53
# num of updates: 2400
# loss: 23.71956
# eval avg reward: 1.20000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.23997
# lr 0.00024
# ============================================================
# time elapsed: 0:00:55
# num of updates: 2500
# loss: 23.61022
# eval avg reward: 1.00000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.22371
# lr 0.00025
# ============================================================
# time elapsed: 0:00:56
# num of updates: 2600
# loss: 23.52295
# eval avg reward: 0.60000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.24130
# lr 0.00026
# ============================================================
# time elapsed: 0:00:58
# num of updates: 2700
# loss: 23.61138
# eval avg reward: 0.80000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.24307
# lr 0.00027
# ============================================================
# time elapsed: 0:01:00
# num of updates: 2800
# loss: 23.66851
# eval avg reward: 1.20000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.24239
# lr 0.00028
# ============================================================
# time elapsed: 0:01:03
# num of updates: 2900
# loss: 23.66989
# eval avg reward: 1.40000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.24352
# lr 0.00029
# ============================================================
# time elapsed: 0:01:05
# num of updates: 3000
# loss: 23.55244
# eval avg reward: -0.40000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.16927
# lr 0.00030
# ============================================================
# time elapsed: 0:01:07
# num of updates: 3100
# loss: 23.65172
# eval avg reward: 1.60000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.17910
# lr 0.00031
# ============================================================
# time elapsed: 0:01:10
# num of updates: 3200
# loss: 23.58639
# eval avg reward: 1.00000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.24439
# lr 0.00032
# ============================================================
# time elapsed: 0:01:12
# num of updates: 3300
# loss: 23.60335
# eval avg reward: 1.40000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.24195
# lr 0.00033
# ============================================================
# time elapsed: 0:01:14
# num of updates: 3400
# loss: 23.51460
# eval avg reward: 1.20000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.24397
# lr 0.00034
# ============================================================
# time elapsed: 0:01:16
# num of updates: 3500
# loss: 23.62101
# eval avg reward: 0.80000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.24490
# lr 0.00035
# ============================================================
# time elapsed: 0:01:19
# num of updates: 3600
# loss: 23.67526
# eval avg reward: 0.00000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.24455
# lr 0.00036
# ============================================================
# time elapsed: 0:01:21
# num of updates: 3700
# loss: 23.55662
# eval avg reward: 1.40000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.24631
# lr 0.00037
# ============================================================
# time elapsed: 0:01:23
# num of updates: 3800
# loss: 23.68416
# eval avg reward: 0.80000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.24669
# lr 0.00038
# ============================================================
# time elapsed: 0:01:25
# num of updates: 3900
# loss: 23.59216
# eval avg reward: 0.60000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.24660
# lr 0.00039
# ============================================================
# time elapsed: 0:01:28
# num of updates: 4000
# loss: 23.67115
# eval avg reward: 0.80000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.15718
# lr 0.00040
# ============================================================
# time elapsed: 0:01:30
# num of updates: 4100
# loss: 23.52404
# eval avg reward: 1.20000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.06617
# lr 0.00041
# ============================================================
# time elapsed: 0:01:32
# num of updates: 4200
# loss: 23.49920
# eval avg reward: 0.60000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.24701
# lr 0.00042
# ============================================================
# time elapsed: 0:01:34
# num of updates: 4300
# loss: 23.69428
# eval avg reward: 0.80000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.24640
# lr 0.00043
# ============================================================
# time elapsed: 0:01:37
# num of updates: 4400
# loss: 23.60054
# eval avg reward: 1.00000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.23968
# lr 0.00044
# ============================================================
# time elapsed: 0:01:39
# num of updates: 4500
# loss: 23.61433
# eval avg reward: 1.20000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.24536
# lr 0.00045
# ============================================================
# time elapsed: 0:01:41
# num of updates: 4600
# loss: 23.66839
# eval avg reward: 1.20000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.24748
# lr 0.00046
# ============================================================
# time elapsed: 0:01:44
# num of updates: 4700
# loss: 23.61834
# eval avg reward: 1.20000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.21072
# lr 0.00047
# ============================================================
# time elapsed: 0:01:46
# num of updates: 4800
# loss: 23.57231
# eval avg reward: 0.60000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.17073
# lr 0.00048
# ============================================================
# time elapsed: 0:01:48
# num of updates: 4900
# loss: 23.59244
# eval avg reward: 0.20000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.24772
# lr 0.00049
# saving current model at: /home/muhender/6.8200/RL-credit-assignment-experiment/logs/dt_runs/dt_umbrella-length-experiment_model_24-05-10-22-23-06.pt
# ============================================================
# time elapsed: 0:01:51
# num of updates: 5000
# loss: 23.56382
# eval avg reward: 0.20000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.24750
# lr 0.00050
# ============================================================
# time elapsed: 0:01:53
# num of updates: 5100
# loss: 23.53698
# eval avg reward: 0.80000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.20135
# lr 0.00051
# ============================================================
# time elapsed: 0:01:55
# num of updates: 5200
# loss: 23.48623
# eval avg reward: 1.00000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.20011
# lr 0.00052
# ============================================================
# time elapsed: 0:01:57
# num of updates: 5300
# loss: 23.51403
# eval avg reward: 0.60000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.24709
# lr 0.00053
# ============================================================
# time elapsed: 0:02:00
# num of updates: 5400
# loss: 23.54193
# eval avg reward: 1.20000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.24815
# lr 0.00054
# achieved average reward:  2.0
# saving max score model at: /home/muhender/6.8200/RL-credit-assignment-experiment/logs/dt_runs/dt_umbrella-length-experiment_model_24-05-10-22-23-06_best.pt
# ============================================================
# time elapsed: 0:02:02
# num of updates: 5500
# loss: 23.57027
# eval avg reward: 2.00000
# best score: 1.80000
# eval_avg_ep_len 4.00000
# grad_norm 0.24772
# lr 0.00055
# ============================================================
# time elapsed: 0:02:04
# num of updates: 5600
# loss: 23.57337
# eval avg reward: 1.00000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.17371
# lr 0.00056
# ============================================================
# time elapsed: 0:02:05
# num of updates: 5700
# loss: 23.61283
# eval avg reward: 0.80000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.24714
# lr 0.00057
# ============================================================
# time elapsed: 0:02:07
# num of updates: 5800
# loss: 23.48737
# eval avg reward: 1.40000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.24795
# lr 0.00058
# ============================================================
# time elapsed: 0:02:09
# num of updates: 5900
# loss: 23.65618
# eval avg reward: 0.40000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.24800
# lr 0.00059
# ============================================================
# time elapsed: 0:02:11
# num of updates: 6000
# loss: 23.59750
# eval avg reward: 1.00000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.24809
# lr 0.00060
# ============================================================
# time elapsed: 0:02:13
# num of updates: 6100
# loss: 23.55562
# eval avg reward: 1.00000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.13158
# lr 0.00061
# achieved average reward:  2.0
# saving max score model at: /home/muhender/6.8200/RL-credit-assignment-experiment/logs/dt_runs/dt_umbrella-length-experiment_model_24-05-10-22-23-06_best.pt
# ============================================================
# time elapsed: 0:02:14
# num of updates: 6200
# loss: 23.41879
# eval avg reward: 2.00000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.13876
# lr 0.00062
# ============================================================
# time elapsed: 0:02:16
# num of updates: 6300
# loss: 23.72825
# eval avg reward: 0.20000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.24384
# lr 0.00063
# ============================================================
# time elapsed: 0:02:18
# num of updates: 6400
# loss: 24.72397
# eval avg reward: 0.00000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.24837
# lr 0.00064
# ============================================================
# time elapsed: 0:02:21
# num of updates: 6500
# loss: 24.75782
# eval avg reward: 0.80000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.10135
# lr 0.00065
# ============================================================
# time elapsed: 0:02:23
# num of updates: 6600
# loss: 24.43051
# eval avg reward: 1.00000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.13304
# lr 0.00066
# ============================================================
# time elapsed: 0:02:25
# num of updates: 6700
# loss: 24.35611
# eval avg reward: 1.20000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.24810
# lr 0.00067
# ============================================================
# time elapsed: 0:02:27
# num of updates: 6800
# loss: 24.32789
# eval avg reward: 0.60000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.21161
# lr 0.00068
# ============================================================
# time elapsed: 0:02:29
# num of updates: 6900
# loss: 24.26836
# eval avg reward: 0.60000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.24844
# lr 0.00069
# ============================================================
# time elapsed: 0:02:31
# num of updates: 7000
# loss: 24.34531
# eval avg reward: 1.20000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.24842
# lr 0.00070
# ============================================================
# time elapsed: 0:02:33
# num of updates: 7100
# loss: 24.23499
# eval avg reward: 0.60000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.24842
# lr 0.00071
# achieved average reward:  2.0
# saving max score model at: /home/muhender/6.8200/RL-credit-assignment-experiment/logs/dt_runs/dt_umbrella-length-experiment_model_24-05-10-22-23-06_best.pt
# ============================================================
# time elapsed: 0:02:36
# num of updates: 7200
# loss: 24.44036
# eval avg reward: 2.00000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.24848
# lr 0.00072
# ============================================================
# time elapsed: 0:02:38
# num of updates: 7300
# loss: 24.40931
# eval avg reward: 1.20000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.15939
# lr 0.00073
# ============================================================
# time elapsed: 0:02:40
# num of updates: 7400
# loss: 24.24212
# eval avg reward: 1.60000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.17080
# lr 0.00074
# ============================================================
# time elapsed: 0:02:42
# num of updates: 7500
# loss: 24.29372
# eval avg reward: 0.40000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.24849
# lr 0.00075
# ============================================================
# time elapsed: 0:02:44
# num of updates: 7600
# loss: 24.25809
# eval avg reward: 0.80000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.21431
# lr 0.00076
# ============================================================
# time elapsed: 0:02:46
# num of updates: 7700
# loss: 24.18205
# eval avg reward: 1.60000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.24151
# lr 0.00077
# ============================================================
# time elapsed: 0:02:48
# num of updates: 7800
# loss: 24.00810
# eval avg reward: 1.40000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.21945
# lr 0.00078
# ============================================================
# time elapsed: 0:02:51
# num of updates: 7900
# loss: 24.16986
# eval avg reward: 1.40000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.24766
# lr 0.00079
# ============================================================
# time elapsed: 0:02:53
# num of updates: 8000
# loss: 23.71536
# eval avg reward: 1.00000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.16192
# lr 0.00080
# achieved average reward:  2.4
# saving max score model at: /home/muhender/6.8200/RL-credit-assignment-experiment/logs/dt_runs/dt_umbrella-length-experiment_model_24-05-10-22-23-06_best.pt
# ============================================================
# time elapsed: 0:02:55
# num of updates: 8100
# loss: 24.04698
# eval avg reward: 2.40000
# best score: 2.00000
# eval_avg_ep_len 4.00000
# grad_norm 0.14046
# lr 0.00081
# ============================================================
# time elapsed: 0:02:58
# num of updates: 8200
# loss: 23.47876
# eval avg reward: 0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.24579
# lr 0.00082
# ============================================================
# time elapsed: 0:03:00
# num of updates: 8300
# loss: 23.50294
# eval avg reward: 1.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.24834
# lr 0.00083
# ============================================================
# time elapsed: 0:03:03
# num of updates: 8400
# loss: 23.61042
# eval avg reward: 0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.11062
# lr 0.00084
# ============================================================
# time elapsed: 0:03:05
# num of updates: 8500
# loss: 23.61241
# eval avg reward: 1.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.24817
# lr 0.00085
# ============================================================
# time elapsed: 0:03:07
# num of updates: 8600
# loss: 23.51406
# eval avg reward: 0.80000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.24784
# lr 0.00086
# ============================================================
# time elapsed: 0:03:10
# num of updates: 8700
# loss: 23.53400
# eval avg reward: 1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.12348
# lr 0.00087
# ============================================================
# time elapsed: 0:03:12
# num of updates: 8800
# loss: 23.53083
# eval avg reward: 1.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.10986
# lr 0.00088
# ============================================================
# time elapsed: 0:03:14
# num of updates: 8900
# loss: 23.50485
# eval avg reward: 0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.11298
# lr 0.00089
# ============================================================
# time elapsed: 0:03:16
# num of updates: 9000
# loss: 23.56557
# eval avg reward: 0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.15508
# lr 0.00090
# ============================================================
# time elapsed: 0:03:19
# num of updates: 9100
# loss: 23.61554
# eval avg reward: 0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.21743
# lr 0.00091
# ============================================================
# time elapsed: 0:03:21
# num of updates: 9200
# loss: 23.55216
# eval avg reward: 0.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.17577
# lr 0.00092
# ============================================================
# time elapsed: 0:03:23
# num of updates: 9300
# loss: 23.50842
# eval avg reward: 0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.15490
# lr 0.00093
# ============================================================
# time elapsed: 0:03:26
# num of updates: 9400
# loss: 23.47593
# eval avg reward: 0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.24802
# lr 0.00094
# ============================================================
# time elapsed: 0:03:28
# num of updates: 9500
# loss: 23.52239
# eval avg reward: 1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.24741
# lr 0.00095
# ============================================================
# time elapsed: 0:03:30
# num of updates: 9600
# loss: 23.43506
# eval avg reward: 0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.06805
# lr 0.00096
# ============================================================
# time elapsed: 0:03:32
# num of updates: 9700
# loss: 23.50276
# eval avg reward: 1.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.24718
# lr 0.00097
# ============================================================
# time elapsed: 0:03:34
# num of updates: 9800
# loss: 23.48062
# eval avg reward: 0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.11860
# lr 0.00098
# ============================================================
# time elapsed: 0:03:37
# num of updates: 9900
# loss: 23.50583
# eval avg reward: 1.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.24810
# lr 0.00099
# saving current model at: /home/muhender/6.8200/RL-credit-assignment-experiment/logs/dt_runs/dt_umbrella-length-experiment_model_24-05-10-22-23-06.pt
# ============================================================
# time elapsed: 0:03:38
# num of updates: 10000
# loss: 23.54169
# eval avg reward: 1.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.24757
# lr 0.00100
# ============================================================
# time elapsed: 0:03:40
# num of updates: 10100
# loss: 24.15191
# eval avg reward: 0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.24693
# lr 0.00100
# ============================================================
# time elapsed: 0:03:42
# num of updates: 10200
# loss: 24.98269
# eval avg reward: 0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.12423
# lr 0.00100
# ============================================================
# time elapsed: 0:03:44
# num of updates: 10300
# loss: 25.01140
# eval avg reward: -0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.09888
# lr 0.00100
# ============================================================
# time elapsed: 0:03:45
# num of updates: 10400
# loss: 25.02745
# eval avg reward: -0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.12978
# lr 0.00100
# ============================================================
# time elapsed: 0:03:47
# num of updates: 10500
# loss: 24.96887
# eval avg reward: -0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.14245
# lr 0.00100
# ============================================================
# time elapsed: 0:03:49
# num of updates: 10600
# loss: 24.73603
# eval avg reward: 0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.24718
# lr 0.00100
# ============================================================
# time elapsed: 0:03:51
# num of updates: 10700
# loss: 24.71749
# eval avg reward: 1.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.24529
# lr 0.00100
# ============================================================
# time elapsed: 0:03:53
# num of updates: 10800
# loss: 24.67343
# eval avg reward: 0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.18432
# lr 0.00100
# ============================================================
# time elapsed: 0:03:56
# num of updates: 10900
# loss: 24.98156
# eval avg reward: 1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.14460
# lr 0.00100
# ============================================================
# time elapsed: 0:03:58
# num of updates: 11000
# loss: 24.58364
# eval avg reward: 0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.24629
# lr 0.00100
# ============================================================
# time elapsed: 0:04:01
# num of updates: 11100
# loss: 24.34164
# eval avg reward: 0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.24484
# lr 0.00100
# ============================================================
# time elapsed: 0:04:03
# num of updates: 11200
# loss: 23.91311
# eval avg reward: 0.80000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.17963
# lr 0.00100
# ============================================================
# time elapsed: 0:04:05
# num of updates: 11300
# loss: 24.44571
# eval avg reward: 0.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.07687
# lr 0.00100
# ============================================================
# time elapsed: 0:04:09
# num of updates: 11400
# loss: 25.05559
# eval avg reward: 1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.14591
# lr 0.00100
# ============================================================
# time elapsed: 0:04:12
# num of updates: 11500
# loss: 25.02333
# eval avg reward: 1.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.09717
# lr 0.00100
# ============================================================
# time elapsed: 0:04:14
# num of updates: 11600
# loss: 25.00846
# eval avg reward: 1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.24683
# lr 0.00100
# ============================================================
# time elapsed: 0:04:16
# num of updates: 11700
# loss: 25.01012
# eval avg reward: 1.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.24658
# lr 0.00100
# ============================================================
# time elapsed: 0:04:19
# num of updates: 11800
# loss: 24.79547
# eval avg reward: 1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.24617
# lr 0.00100
# ============================================================
# time elapsed: 0:04:21
# num of updates: 11900
# loss: 24.63181
# eval avg reward: 0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.24641
# lr 0.00100
# ============================================================
# time elapsed: 0:04:24
# num of updates: 12000
# loss: 24.78896
# eval avg reward: 0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.22374
# lr 0.00100
# ============================================================
# time elapsed: 0:04:26
# num of updates: 12100
# loss: 25.00855
# eval avg reward: 0.80000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.24628
# lr 0.00100
# ============================================================
# time elapsed: 0:04:28
# num of updates: 12200
# loss: 25.03289
# eval avg reward: -1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.16913
# lr 0.00100
# ============================================================
# time elapsed: 0:04:30
# num of updates: 12300
# loss: 25.02051
# eval avg reward: 0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.14052
# lr 0.00100
# ============================================================
# time elapsed: 0:04:32
# num of updates: 12400
# loss: 25.03078
# eval avg reward: 0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.15607
# lr 0.00100
# ============================================================
# time elapsed: 0:04:34
# num of updates: 12500
# loss: 25.03033
# eval avg reward: 0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.24741
# lr 0.00100
# ============================================================
# time elapsed: 0:04:37
# num of updates: 12600
# loss: 25.01806
# eval avg reward: 0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.13868
# lr 0.00100
# ============================================================
# time elapsed: 0:04:39
# num of updates: 12700
# loss: 25.02765
# eval avg reward: 0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.10012
# lr 0.00100
# ============================================================
# time elapsed: 0:04:42
# num of updates: 12800
# loss: 25.01570
# eval avg reward: -0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.06406
# lr 0.00100
# ============================================================
# time elapsed: 0:04:44
# num of updates: 12900
# loss: 24.85001
# eval avg reward: 1.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.09621
# lr 0.00100
# ============================================================
# time elapsed: 0:04:47
# num of updates: 13000
# loss: 24.48695
# eval avg reward: 1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.13943
# lr 0.00100
# ============================================================
# time elapsed: 0:04:49
# num of updates: 13100
# loss: 24.89056
# eval avg reward: 1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.16421
# lr 0.00100
# ============================================================
# time elapsed: 0:04:51
# num of updates: 13200
# loss: 24.81945
# eval avg reward: 0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.04803
# lr 0.00100
# ============================================================
# time elapsed: 0:04:53
# num of updates: 13300
# loss: 24.79924
# eval avg reward: 1.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.24424
# lr 0.00100
# ============================================================
# time elapsed: 0:04:56
# num of updates: 13400
# loss: 24.78822
# eval avg reward: 0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.09658
# lr 0.00100
# ============================================================
# time elapsed: 0:04:57
# num of updates: 13500
# loss: 24.81853
# eval avg reward: 1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.15985
# lr 0.00100
# ============================================================
# time elapsed: 0:04:59
# num of updates: 13600
# loss: 24.83644
# eval avg reward: 0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.05716
# lr 0.00100
# ============================================================
# time elapsed: 0:05:01
# num of updates: 13700
# loss: 24.78838
# eval avg reward: 0.80000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.05756
# lr 0.00100
# ============================================================
# time elapsed: 0:05:03
# num of updates: 13800
# loss: 24.72925
# eval avg reward: 1.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.10489
# lr 0.00100
# ============================================================
# time elapsed: 0:05:05
# num of updates: 13900
# loss: 24.65389
# eval avg reward: 1.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.19901
# lr 0.00100
# ============================================================
# time elapsed: 0:05:06
# num of updates: 14000
# loss: 24.58877
# eval avg reward: 0.80000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.12982
# lr 0.00100
# ============================================================
# time elapsed: 0:05:08
# num of updates: 14100
# loss: 24.50396
# eval avg reward: 1.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.17858
# lr 0.00100
# ============================================================
# time elapsed: 0:05:10
# num of updates: 14200
# loss: 24.46366
# eval avg reward: 1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.05352
# lr 0.00100
# ============================================================
# time elapsed: 0:05:12
# num of updates: 14300
# loss: 24.54622
# eval avg reward: 1.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.16560
# lr 0.00100
# ============================================================
# time elapsed: 0:05:14
# num of updates: 14400
# loss: 24.54279
# eval avg reward: 1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.08982
# lr 0.00100
# ============================================================
# time elapsed: 0:05:15
# num of updates: 14500
# loss: 24.45422
# eval avg reward: 0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.10394
# lr 0.00100
# ============================================================
# time elapsed: 0:05:17
# num of updates: 14600
# loss: 24.50722
# eval avg reward: 0.80000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.07124
# lr 0.00100
# ============================================================
# time elapsed: 0:05:19
# num of updates: 14700
# loss: 24.47935
# eval avg reward: 1.80000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.05248
# lr 0.00100
# ============================================================
# time elapsed: 0:05:21
# num of updates: 14800
# loss: 24.44045
# eval avg reward: 1.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.20460
# lr 0.00100
# ============================================================
# time elapsed: 0:05:22
# num of updates: 14900
# loss: 24.48982
# eval avg reward: 0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.06020
# lr 0.00100
# saving current model at: /home/muhender/6.8200/RL-credit-assignment-experiment/logs/dt_runs/dt_umbrella-length-experiment_model_24-05-10-22-23-06.pt
# ============================================================
# time elapsed: 0:05:24
# num of updates: 15000
# loss: 24.32427
# eval avg reward: 2.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.21459
# lr 0.00100
# ============================================================
# time elapsed: 0:05:26
# num of updates: 15100
# loss: 24.51291
# eval avg reward: 0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.18753
# lr 0.00100
# ============================================================
# time elapsed: 0:05:28
# num of updates: 15200
# loss: 24.67441
# eval avg reward: 2.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.04875
# lr 0.00100
# ============================================================
# time elapsed: 0:05:30
# num of updates: 15300
# loss: 24.87921
# eval avg reward: -0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.18746
# lr 0.00100
# ============================================================
# time elapsed: 0:05:32
# num of updates: 15400
# loss: 25.01467
# eval avg reward: -0.80000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.11489
# lr 0.00100
# ============================================================
# time elapsed: 0:05:33
# num of updates: 15500
# loss: 25.03070
# eval avg reward: -0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.05477
# lr 0.00100
# ============================================================
# time elapsed: 0:05:35
# num of updates: 15600
# loss: 25.02727
# eval avg reward: 1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.03982
# lr 0.00100
# ============================================================
# time elapsed: 0:05:37
# num of updates: 15700
# loss: 25.01889
# eval avg reward: 0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.14831
# lr 0.00100
# ============================================================
# time elapsed: 0:05:39
# num of updates: 15800
# loss: 25.02610
# eval avg reward: -0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.06548
# lr 0.00100
# ============================================================
# time elapsed: 0:05:40
# num of updates: 15900
# loss: 25.01286
# eval avg reward: 0.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.20555
# lr 0.00100
# ============================================================
# time elapsed: 0:05:42
# num of updates: 16000
# loss: 25.02125
# eval avg reward: -0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.05763
# lr 0.00100
# ============================================================
# time elapsed: 0:05:44
# num of updates: 16100
# loss: 25.02161
# eval avg reward: 1.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.12561
# lr 0.00100
# ============================================================
# time elapsed: 0:05:46
# num of updates: 16200
# loss: 25.02057
# eval avg reward: 0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.07759
# lr 0.00100
# ============================================================
# time elapsed: 0:05:47
# num of updates: 16300
# loss: 25.02523
# eval avg reward: 0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.14994
# lr 0.00100
# ============================================================
# time elapsed: 0:05:49
# num of updates: 16400
# loss: 25.01321
# eval avg reward: -0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.03599
# lr 0.00100
# ============================================================
# time elapsed: 0:05:51
# num of updates: 16500
# loss: 25.02406
# eval avg reward: -1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.04531
# lr 0.00100
# ============================================================
# time elapsed: 0:05:53
# num of updates: 16600
# loss: 25.00437
# eval avg reward: 0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.16476
# lr 0.00100
# ============================================================
# time elapsed: 0:05:55
# num of updates: 16700
# loss: 25.01118
# eval avg reward: -0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.03359
# lr 0.00100
# ============================================================
# time elapsed: 0:05:56
# num of updates: 16800
# loss: 25.01159
# eval avg reward: -0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.14520
# lr 0.00100
# ============================================================
# time elapsed: 0:05:58
# num of updates: 16900
# loss: 25.01187
# eval avg reward: 0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.04729
# lr 0.00100
# ============================================================
# time elapsed: 0:06:00
# num of updates: 17000
# loss: 25.02655
# eval avg reward: 0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.03955
# lr 0.00100
# ============================================================
# time elapsed: 0:06:02
# num of updates: 17100
# loss: 25.01413
# eval avg reward: -0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.08293
# lr 0.00100
# ============================================================
# time elapsed: 0:06:03
# num of updates: 17200
# loss: 25.00893
# eval avg reward: 1.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.04552
# lr 0.00100
# ============================================================
# time elapsed: 0:06:05
# num of updates: 17300
# loss: 25.00497
# eval avg reward: -1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.23378
# lr 0.00100
# ============================================================
# time elapsed: 0:06:07
# num of updates: 17400
# loss: 25.01501
# eval avg reward: 1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.13055
# lr 0.00100
# ============================================================
# time elapsed: 0:06:09
# num of updates: 17500
# loss: 25.00548
# eval avg reward: 0.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.05320
# lr 0.00100
# ============================================================
# time elapsed: 0:06:11
# num of updates: 17600
# loss: 25.02210
# eval avg reward: -0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.01859
# lr 0.00100
# ============================================================
# time elapsed: 0:06:12
# num of updates: 17700
# loss: 25.01066
# eval avg reward: -0.80000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.13405
# lr 0.00100
# ============================================================
# time elapsed: 0:06:14
# num of updates: 17800
# loss: 25.01354
# eval avg reward: -0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.09946
# lr 0.00100
# ============================================================
# time elapsed: 0:06:16
# num of updates: 17900
# loss: 25.02384
# eval avg reward: 0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.12248
# lr 0.00100
# ============================================================
# time elapsed: 0:06:18
# num of updates: 18000
# loss: 25.01161
# eval avg reward: -0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.04768
# lr 0.00100
# ============================================================
# time elapsed: 0:06:20
# num of updates: 18100
# loss: 25.01126
# eval avg reward: -0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.13480
# lr 0.00100
# ============================================================
# time elapsed: 0:06:22
# num of updates: 18200
# loss: 25.00495
# eval avg reward: 0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.03935
# lr 0.00100
# ============================================================
# time elapsed: 0:06:23
# num of updates: 18300
# loss: 25.00222
# eval avg reward: 0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.07318
# lr 0.00100
# ============================================================
# time elapsed: 0:06:25
# num of updates: 18400
# loss: 25.00919
# eval avg reward: -0.80000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.08090
# lr 0.00100
# ============================================================
# time elapsed: 0:06:27
# num of updates: 18500
# loss: 25.01402
# eval avg reward: -0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.11098
# lr 0.00100
# ============================================================
# time elapsed: 0:06:29
# num of updates: 18600
# loss: 25.01128
# eval avg reward: -1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.03151
# lr 0.00100
# ============================================================
# time elapsed: 0:06:30
# num of updates: 18700
# loss: 25.01095
# eval avg reward: 1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.02297
# lr 0.00100
# ============================================================
# time elapsed: 0:06:32
# num of updates: 18800
# loss: 25.01120
# eval avg reward: 0.80000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.15537
# lr 0.00100
# ============================================================
# time elapsed: 0:06:34
# num of updates: 18900
# loss: 25.00480
# eval avg reward: 0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.06029
# lr 0.00100
# ============================================================
# time elapsed: 0:06:36
# num of updates: 19000
# loss: 25.01076
# eval avg reward: 0.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.13826
# lr 0.00100
# ============================================================
# time elapsed: 0:06:38
# num of updates: 19100
# loss: 25.01656
# eval avg reward: 1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.02737
# lr 0.00100
# ============================================================
# time elapsed: 0:06:40
# num of updates: 19200
# loss: 24.99264
# eval avg reward: 0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.04801
# lr 0.00100
# ============================================================
# time elapsed: 0:06:41
# num of updates: 19300
# loss: 25.01516
# eval avg reward: -0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.03857
# lr 0.00100
# ============================================================
# time elapsed: 0:06:43
# num of updates: 19400
# loss: 25.00732
# eval avg reward: 0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.04870
# lr 0.00100
# ============================================================
# time elapsed: 0:06:45
# num of updates: 19500
# loss: 25.01546
# eval avg reward: 0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.10354
# lr 0.00100
# ============================================================
# time elapsed: 0:06:47
# num of updates: 19600
# loss: 25.01112
# eval avg reward: 0.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.06382
# lr 0.00100
# ============================================================
# time elapsed: 0:06:48
# num of updates: 19700
# loss: 24.99725
# eval avg reward: 0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.07103
# lr 0.00100
# ============================================================
# time elapsed: 0:06:50
# num of updates: 19800
# loss: 25.00270
# eval avg reward: 0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.10001
# lr 0.00100
# ============================================================
# time elapsed: 0:06:52
# num of updates: 19900
# loss: 25.01859
# eval avg reward: 0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.01381
# lr 0.00100
# saving current model at: /home/muhender/6.8200/RL-credit-assignment-experiment/logs/dt_runs/dt_umbrella-length-experiment_model_24-05-10-22-23-06.pt
# ============================================================
# time elapsed: 0:06:54
# num of updates: 20000
# loss: 25.00979
# eval avg reward: -0.80000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.01777
# lr 0.00100
# ============================================================
# time elapsed: 0:06:55
# num of updates: 20100
# loss: 25.00856
# eval avg reward: 0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.09074
# lr 0.00100
# ============================================================
# time elapsed: 0:06:57
# num of updates: 20200
# loss: 25.01074
# eval avg reward: 1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.08192
# lr 0.00100
# ============================================================
# time elapsed: 0:06:59
# num of updates: 20300
# loss: 25.00829
# eval avg reward: -0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.10251
# lr 0.00100
# ============================================================
# time elapsed: 0:07:01
# num of updates: 20400
# loss: 25.00834
# eval avg reward: -1.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.04241
# lr 0.00100
# ============================================================
# time elapsed: 0:07:02
# num of updates: 20500
# loss: 25.01238
# eval avg reward: 1.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.15316
# lr 0.00100
# ============================================================
# time elapsed: 0:07:04
# num of updates: 20600
# loss: 25.01076
# eval avg reward: 0.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.03721
# lr 0.00100
# ============================================================
# time elapsed: 0:07:06
# num of updates: 20700
# loss: 25.01299
# eval avg reward: -0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.07280
# lr 0.00100
# ============================================================
# time elapsed: 0:07:08
# num of updates: 20800
# loss: 25.01462
# eval avg reward: 0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.03986
# lr 0.00100
# ============================================================
# time elapsed: 0:07:09
# num of updates: 20900
# loss: 25.01603
# eval avg reward: -0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.02705
# lr 0.00100
# ============================================================
# time elapsed: 0:07:11
# num of updates: 21000
# loss: 25.00662
# eval avg reward: 1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# ...
# time elapsed: 0:07:50
# num of updates: 23200
# loss: 25.00476
# eval avg reward: -0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.02830
# lr 0.00100
# ============================================================
# time elapsed: 0:07:51
# num of updates: 23300
# loss: 25.00958
# eval avg reward: 0.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.07191
# lr 0.00100
# ============================================================
# time elapsed: 0:07:53
# num of updates: 23400
# loss: 25.00820
# eval avg reward: 1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.07675
# lr 0.00100
# ============================================================
# time elapsed: 0:07:55
# num of updates: 23500
# loss: 25.01090
# eval avg reward: -0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.01275
# lr 0.00100
# ============================================================
# time elapsed: 0:07:57
# num of updates: 23600
# loss: 24.99764
# eval avg reward: -0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.01704
# lr 0.00100
# ============================================================
# time elapsed: 0:07:59
# num of updates: 23700
# loss: 25.00727
# eval avg reward: -0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.02617
# lr 0.00100
# ============================================================
# time elapsed: 0:08:01
# num of updates: 23800
# loss: 25.00902
# eval avg reward: 1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.05314
# lr 0.00100
# ============================================================
# time elapsed: 0:08:03
# num of updates: 23900
# loss: 25.00714
# eval avg reward: 1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.08441
# lr 0.00100
# ============================================================
# time elapsed: 0:08:05
# num of updates: 24000
# loss: 25.00272
# eval avg reward: -0.80000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.03952
# lr 0.00100
# ============================================================
# time elapsed: 0:08:07
# num of updates: 24100
# loss: 25.00924
# eval avg reward: -0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.02782
# lr 0.00100
# ============================================================
# time elapsed: 0:08:09
# num of updates: 24200
# loss: 25.00423
# eval avg reward: 0.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.05266
# lr 0.00100
# ============================================================
# time elapsed: 0:08:11
# num of updates: 24300
# loss: 25.00424
# eval avg reward: -0.80000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.08297
# lr 0.00100
# ============================================================
# time elapsed: 0:08:13
# num of updates: 24400
# loss: 25.01166
# eval avg reward: 0.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.02639
# lr 0.00100
# ============================================================
# time elapsed: 0:08:15
# num of updates: 24500
# loss: 25.00089
# eval avg reward: 0.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.07230
# lr 0.00100
# ============================================================
# time elapsed: 0:08:17
# num of updates: 24600
# loss: 25.00425
# eval avg reward: 0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.01692
# lr 0.00100
# ============================================================
# time elapsed: 0:08:19
# num of updates: 24700
# loss: 25.00402
# eval avg reward: -0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.01964
# lr 0.00100
# ============================================================
# time elapsed: 0:08:22
# num of updates: 24800
# loss: 25.00401
# eval avg reward: -0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.02789
# lr 0.00100
# ============================================================
# time elapsed: 0:08:24
# num of updates: 24900
# loss: 25.00741
# eval avg reward: 0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.01540
# lr 0.00100
# saving current model at: /home/muhender/6.8200/RL-credit-assignment-experiment/logs/dt_runs/dt_umbrella-length-experiment_model_24-05-10-22-23-06.pt
# ============================================================
# time elapsed: 0:08:26
# num of updates: 25000
# loss: 25.00895
# eval avg reward: -0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.04616
# lr 0.00100
# ============================================================
# time elapsed: 0:08:28
# num of updates: 25100
# loss: 25.00146
# eval avg reward: -0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.02654
# lr 0.00100
# ============================================================
# time elapsed: 0:08:30
# num of updates: 25200
# loss: 25.00805
# eval avg reward: -0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.02118
# lr 0.00100
# ============================================================
# time elapsed: 0:08:32
# num of updates: 25300
# loss: 25.00805
# eval avg reward: 1.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.01246
# lr 0.00100
# ============================================================
# time elapsed: 0:08:34
# num of updates: 25400
# loss: 25.00331
# eval avg reward: -0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.04857
# lr 0.00100
# ============================================================
# time elapsed: 0:08:36
# num of updates: 25500
# loss: 25.01239
# eval avg reward: -0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.06538
# lr 0.00100
# ============================================================
# time elapsed: 0:08:38
# num of updates: 25600
# loss: 25.01236
# eval avg reward: -0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.02132
# lr 0.00100
# ============================================================
# time elapsed: 0:08:40
# num of updates: 25700
# loss: 25.00815
# eval avg reward: 0.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.02671
# lr 0.00100
# ============================================================
# time elapsed: 0:08:42
# num of updates: 25800
# loss: 25.00515
# eval avg reward: -0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.01856
# lr 0.00100
# ============================================================
# time elapsed: 0:08:44
# num of updates: 25900
# loss: 25.00613
# eval avg reward: -0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.08443
# lr 0.00100
# ============================================================
# time elapsed: 0:08:46
# num of updates: 26000
# loss: 25.00309
# eval avg reward: -0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.07035
# lr 0.00100
# ============================================================
# time elapsed: 0:08:49
# num of updates: 26100
# loss: 25.00540
# eval avg reward: -0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.07019
# lr 0.00100
# ============================================================
# time elapsed: 0:08:51
# num of updates: 26200
# loss: 25.00663
# eval avg reward: -1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.03581
# lr 0.00100
# ============================================================
# time elapsed: 0:08:53
# num of updates: 26300
# loss: 25.01060
# eval avg reward: -1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.05674
# lr 0.00100
# ============================================================
# time elapsed: 0:08:55
# num of updates: 26400
# loss: 25.00909
# eval avg reward: -1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.04045
# lr 0.00100
# ============================================================
# time elapsed: 0:08:57
# num of updates: 26500
# loss: 25.00321
# eval avg reward: -0.80000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.01562
# lr 0.00100
# ============================================================
# time elapsed: 0:08:59
# num of updates: 26600
# loss: 25.00407
# eval avg reward: 1.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.02277
# lr 0.00100
# ============================================================
# time elapsed: 0:09:00
# num of updates: 26700
# loss: 25.01482
# eval avg reward: -0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.01825
# lr 0.00100
# ============================================================
# time elapsed: 0:09:02
# num of updates: 26800
# loss: 25.00451
# eval avg reward: -0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.02383
# lr 0.00100
# ============================================================
# time elapsed: 0:09:04
# num of updates: 26900
# loss: 25.00400
# eval avg reward: -0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.01622
# lr 0.00100
# ============================================================
# time elapsed: 0:09:06
# num of updates: 27000
# loss: 25.01057
# eval avg reward: -0.80000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.03191
# lr 0.00100
# ============================================================
# time elapsed: 0:09:08
# num of updates: 27100
# loss: 25.00376
# eval avg reward: 0.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.01735
# lr 0.00100
# ============================================================
# time elapsed: 0:09:10
# num of updates: 27200
# loss: 25.00894
# eval avg reward: 0.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.03095
# lr 0.00100
# ============================================================
# time elapsed: 0:09:11
# num of updates: 27300
# loss: 25.00933
# eval avg reward: -0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.03870
# lr 0.00100
# ============================================================
# time elapsed: 0:09:13
# num of updates: 27400
# loss: 25.01149
# eval avg reward: -1.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.02867
# lr 0.00100
# ============================================================
# time elapsed: 0:09:15
# num of updates: 27500
# loss: 25.01046
# eval avg reward: -0.80000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.02787
# lr 0.00100
# ============================================================
# time elapsed: 0:09:17
# num of updates: 27600
# loss: 25.01519
# eval avg reward: 0.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.04973
# lr 0.00100
# ============================================================
# time elapsed: 0:09:18
# num of updates: 27700
# loss: 25.01379
# eval avg reward: 0.80000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.02388
# lr 0.00100
# ============================================================
# time elapsed: 0:09:20
# num of updates: 27800
# loss: 25.00134
# eval avg reward: -0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.02747
# lr 0.00100
# ============================================================
# time elapsed: 0:09:22
# num of updates: 27900
# loss: 25.01018
# eval avg reward: -0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.03157
# lr 0.00100
# ============================================================
# time elapsed: 0:09:24
# num of updates: 28000
# loss: 25.00648
# eval avg reward: 0.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.01323
# lr 0.00100
# ============================================================
# time elapsed: 0:09:26
# num of updates: 28100
# loss: 25.00249
# eval avg reward: -0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.01947
# lr 0.00100
# ============================================================
# time elapsed: 0:09:28
# num of updates: 28200
# loss: 25.01280
# eval avg reward: 0.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.01495
# lr 0.00100
# ============================================================
# time elapsed: 0:09:30
# num of updates: 28300
# loss: 25.01081
# eval avg reward: 0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.06162
# lr 0.00100
# ============================================================
# time elapsed: 0:09:31
# num of updates: 28400
# loss: 25.00527
# eval avg reward: 0.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.04394
# lr 0.00100
# ============================================================
# time elapsed: 0:09:33
# num of updates: 28500
# loss: 25.00563
# eval avg reward: -0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.03206
# lr 0.00100
# ============================================================
# time elapsed: 0:09:35
# num of updates: 28600
# loss: 25.00866
# eval avg reward: 0.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.03404
# lr 0.00100
# ============================================================
# time elapsed: 0:09:37
# num of updates: 28700
# loss: 25.00214
# eval avg reward: 0.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.05217
# lr 0.00100
# ============================================================
# time elapsed: 0:09:39
# num of updates: 28800
# loss: 25.00978
# eval avg reward: 0.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.06823
# lr 0.00100
# ============================================================
# time elapsed: 0:09:41
# num of updates: 28900
# loss: 25.00920
# eval avg reward: -0.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.02396
# lr 0.00100
# ============================================================
# time elapsed: 0:09:43
# num of updates: 29000
# loss: 25.00202
# eval avg reward: -0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.01218
# lr 0.00100
# ============================================================
# time elapsed: 0:09:45
# num of updates: 29100
# loss: 25.01212
# eval avg reward: 0.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.01333
# lr 0.00100
# ============================================================
# time elapsed: 0:09:47
# num of updates: 29200
# loss: 25.00754
# eval avg reward: -0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.04418
# lr 0.00100
# ============================================================
# time elapsed: 0:09:48
# num of updates: 29300
# loss: 25.00564
# eval avg reward: -0.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.03090
# lr 0.00100
# ============================================================
# time elapsed: 0:09:50
# num of updates: 29400
# loss: 25.00334
# eval avg reward: 1.40000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.06752
# lr 0.00100
# ============================================================
# time elapsed: 0:09:52
# num of updates: 29500
# loss: 25.00696
# eval avg reward: -1.20000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.05522
# lr 0.00100
# ============================================================
# time elapsed: 0:09:54
# num of updates: 29600
# loss: 25.00707
# eval avg reward: 0.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.02968
# lr 0.00100
# ============================================================
# time elapsed: 0:09:56
# num of updates: 29700
# loss: 25.00297
# eval avg reward: 0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.01343
# lr 0.00100
# ============================================================
# time elapsed: 0:09:57
# num of updates: 29800
# loss: 25.00316
# eval avg reward: 1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.09080
# lr 0.00100
# ============================================================
# time elapsed: 0:09:59
# num of updates: 29900
# loss: 25.00967
# eval avg reward: 0.60000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.04725
# lr 0.00100
# saving current model at: /home/muhender/6.8200/RL-credit-assignment-experiment/logs/dt_runs/dt_umbrella-length-experiment_model_24-05-10-22-23-06.pt
# ============================================================
# time elapsed: 0:10:01
# num of updates: 30000
# loss: 25.00295
# eval avg reward: -1.00000
# best score: 2.40000
# eval_avg_ep_len 4.00000
# grad_norm 0.03767
# lr 0.00100
# ============================================================
# finished training!
# ============================================================
# started training at: 24-05-10-22-23-06
# finished training at: 24-05-10-22-33-07
# total training time: 0:10:01
# best score: 2.40000
# saved max d4rl score model at: /home/muhender/6.8200/RL-credit-assignment-experiment/logs/dt_runs/dt_umbrella-length-experiment_model_24-05-10-22-23-06_best.pt
# saved last updated model at: /home/muhender/6.8200/RL-credit-assignment-experiment/logs/dt_runs/dt_umbrella-length-experiment_model_24-05-10-22-23-06.pt
# ============================================================

# %%
callback.plot_eval_results()

# %%
report.sort_values(by=['train/iteration', 'train/update_idx']).reset_index()['train/loss'].plot()
# Out:
# <Axes: >

# %%
# rtg_command = np.linspace(config.rtg_range_check[0], config.rtg_range_check[1], 30)
rtg_command = np.linspace(-1.5, 1.5, 20)

rtg_result = []

for rtg in rtg_command:
	res = evaluate_on_env(
		model=model,
		traj_dataset=traj_dataset,
		device=device,
		context_len=config.context_len,
		env=env,
		rtg_target=rtg,
		num_eval_ep=200
	)
	rtg_result.append(res['eval/avg_reward'])

plt.plot(rtg_command, rtg_result, 'r')
plt.plot(rtg_command, rtg_command, 'b')
plt.xlabel("rtg_command")
plt.ylabel("rtg_result")


plt.legend(["achieved", "commanded", "best"])
