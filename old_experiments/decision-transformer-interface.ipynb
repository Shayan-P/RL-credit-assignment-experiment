# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn

import sys

sys.path.append('../')

# from algorithms.sequence_models.old_decision_transformer.decision_transformer.decision_transformer import DecisionTransformer
from algorithms.sequence_models.decision_transformer.decision_transformer import DecisionTransformer
from algorithms.sequence_models.evaluate import evaluate_on_env
from data.random_walk_dataset import RandomWalkDataset
from envs.random_walk import RandomWalkEnv
from data.trajectory import LimitedContextWrapper
from algorithms.sequence_models.config import TrainConfig
from algorithms.sequence_models.decision_transformer.trainer import TrainerDT

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# pygame 2.5.2 (SDL 2.28.2, Python 3.10.14)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 2024-05-10 13:02:23.643263: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-10 13:02:24.026359: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-10 13:02:24.800782: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# device(type='cuda')

# %%
class CustomCallback:
	def __init__(self, env, model, optimizer, logger, device, traj_dataset, config, rtgs=[]):
		self.env = env
		self.model = model
		self.optimizer = optimizer
		self.logger = logger
		self.device = device
		self.traj_dataset = traj_dataset
		self.config = config
		self.rtgs = rtgs
		self.eval_results = []
		
	def callback(self, df, **kwargs):
		results = evaluate_on_env(
			model=self.model, traj_dataset=self.traj_dataset,
			device=self.device, context_len=self.config.context_len,
			env=self.env, rtg_target=self.config.rtg_main,
			num_eval_ep=self.config.num_eval_ep,
			max_test_ep_len=self.config.max_eval_ep_len)
		self.logger.log(
				   model=self.model,
				   loss=df['train/loss'].sum(),
				   eval_avg_reward=results['eval/avg_reward'],
				   eval_avg_ep_len=results['eval/avg_ep_len'],
				   grad_norm=max(torch.norm(param.grad) for param in self.model.parameters() if param.grad is not None),
				   lr=self.optimizer.param_groups[0]['lr'],
				   important={"grad_norm", "lr"})
		res = {}
		for rtg in self.rtgs:
			res[rtg] = evaluate_on_env(
				model=self.model,
				traj_dataset=self.traj_dataset,
				device=self.device,
				context_len=self.config.context_len,
				env=self.env,
				rtg_target=rtg,
				num_eval_ep=self.config.num_eval_ep
			)
		self.eval_results.append(res)
	
	def plot_eval_results(self):
		plt.figure()
		for rtg in self.rtgs:
			plt.plot([res[rtg]['eval/avg_reward'] for res in self.eval_results])
		plt.xlabel('iteration')
		plt.ylabel('avg_reward')
		plt.legend([f'r={rtg:.2f}' for rtg in self.rtgs])

		plt.figure()
		
		for rtg in self.rtgs:
			n = len(self.eval_results)
			plt.plot(range(n//2, n), [res[rtg]['eval/avg_reward'] for res in self.eval_results[n//2:]])
			
		plt.xlabel('iteration')
		plt.ylabel('avg_reward')
		plt.legend([f'r={rtg:.2f}' for rtg in self.rtgs])
# Out:
# /snap/pycharm-professional/387/plugins/python/helpers/pydev/pydevd_plugins/__init__.py:2: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('pydevd_plugins')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   __import__('pkg_resources').declare_namespace(__name__)
# /snap/pycharm-professional/387/plugins/python/helpers/pydev/pydevd_plugins/extensions/__init__.py:2: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('pydevd_plugins.extensions')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   __import__('pkg_resources').declare_namespace(__name__)
# /snap/pycharm-professional/387/plugins/python/helpers/pydev/pydevd_plugins/extensions/types/__init__.py:2: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('pydevd_plugins.extensions.types')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   __import__('pkg_resources').declare_namespace(__name__)

# %%
env = RandomWalkEnv(num_nodes=10, weight_max=10, reach_the_goal_reward=10, max_episode_length=20)
config = TrainConfig(max_eval_ep_len=20, context_len=25, rtg_range_check=(-10, 10), rtg_main=5)
traj_dataset = RandomWalkDataset(env, n_trajectories=500, reward_scale=20)
# Out:
# collecting trajectories:   0%|          | 0/500 [00:00<?, ?it/s]
# Dataset Info:
# episode_max_length: 20
# reward_scale: 20
# return min=-127, max=9 mean=-26.214132762312634
# state_mean: [0.22341185 0.10516298 0.09897692 0.09302879 0.09374256 0.08612896
#  0.1044492  0.09731144 0.09778729 0.        ]
# state_std: [0.41653211 0.30676331 0.29863103 0.29047278 0.29147023 0.28055438
#  0.30584239 0.29638139 0.29702683 0.        ]
# gamma: 1

# %%
model = DecisionTransformer(
			state_dim=traj_dataset.state_dim(),
			act_dim=traj_dataset.action_dim(),
			n_blocks=config.n_blocks,
			h_dim=config.embed_dim,
			context_len=config.context_len,
			n_heads=config.n_heads,
			drop_p=config.dropout_p,
).to(device)

optimizer = torch.optim.AdamW(model.parameters(), lr=config.lr, weight_decay=config.wt_decay)

scheduler = torch.optim.lr_scheduler.LambdaLR(
	optimizer,
	lambda steps: min((steps+1)/config.warmup_steps, 1)
)

loss_fn = nn.MSELoss(reduction='mean')

trainer = TrainerDT(name='random-walk-another', model=model,
					optimizer=optimizer, loss_fn=loss_fn,
					dataset=LimitedContextWrapper(traj_dataset, context_len=config.context_len),
					device=device, config=config, scheduler=scheduler)

callback = CustomCallback(env=env, model=model,
						  optimizer=optimizer, logger=trainer.logger, device=device, traj_dataset=traj_dataset, config=config,
						  rtgs=np.linspace(config.rtg_range_check[0], config.rtg_range_check[1], 5))

trainer.register_callback(callback.callback)

print("number of parameters", sum(np.prod(param.shape) for param in model.parameters()))
# Out:
# collecting trajectories:   0%|          | 0/500 [00:00<?, ?it/s]
# Dataset Info:
# episode_max_length: 20
# reward_scale: 20
# return min=-136, max=9 mean=-32.749045158391375
# state_mean: [0.20669512 0.10132554 0.09975286 0.09773085 0.09256347 0.1002022
#  0.0959335  0.10671759 0.09907886 0.        ]
# state_std: [0.40493487 0.30175931 0.2996702  0.29695038 0.28981973 0.30026941
#  0.29450002 0.30875386 0.29876787 0.        ]
# gamma: 1
# number of parameters 1125141

# %%
report = trainer.train()
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# achieved average reward:  -18.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-another_model_24-05-09-20-50-55_best.pt
# saving current model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-another_model_24-05-09-20-50-55.pt
# ============================================================
# time elapsed: 0:00:15
# num of updates: 100
# loss: 28.14915
# eval avg reward: -18.00000
# best score: -inf
# eval_avg_ep_len 5.00000
# grad_norm 0.18951
# lr 0.00001
# achieved average reward:  4.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-another_model_24-05-09-20-50-55_best.pt
# saving current model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-another_model_24-05-09-20-50-55.pt
# ============================================================
# time elapsed: 0:00:20
# num of updates: 200
# loss: 14.82598
# eval avg reward: 4.00000
# best score: -18.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.11189
# lr 0.00002
# achieved average reward:  4.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-another_model_24-05-09-20-50-55_best.pt
# saving current model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-another_model_24-05-09-20-50-55.pt
# ============================================================
# time elapsed: 0:00:21
# num of updates: 300
# loss: 9.90377
# eval avg reward: 4.00000
# best score: 4.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.08037
# lr 0.00003
# achieved average reward:  4.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-another_model_24-05-09-20-50-55_best.pt
# saving current model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-another_model_24-05-09-20-50-55.pt
# ============================================================
# time elapsed: 0:00:23
# num of updates: 400
# loss: 9.39785
# eval avg reward: 4.00000
# best score: 4.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.09592
# lr 0.00004
# achieved average reward:  4.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-another_model_24-05-09-20-50-55_best.pt
# saving current model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-another_model_24-05-09-20-50-55.pt
# ============================================================
# time elapsed: 0:00:25
# num of updates: 500
# loss: 9.15240
# eval avg reward: 4.00000
# best score: 4.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.08531
# lr 0.00005
# achieved average reward:  4.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-another_model_24-05-09-20-50-55_best.pt
# saving current model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-another_model_24-05-09-20-50-55.pt
# ============================================================
# time elapsed: 0:00:27
# num of updates: 600
# loss: 8.95734
# eval avg reward: 4.00000
# best score: 4.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.08731
# lr 0.00006
# achieved average reward:  4.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-another_model_24-05-09-20-50-55_best.pt
# saving current model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-another_model_24-05-09-20-50-55.pt
# ============================================================
# time elapsed: 0:00:29
# num of updates: 700
# loss: 8.78632
# eval avg reward: 4.00000
# best score: 4.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.09733
# lr 0.00007
# achieved average reward:  4.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-another_model_24-05-09-20-50-55_best.pt
# saving current model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-another_model_24-05-09-20-50-55.pt
# ============================================================
# time elapsed: 0:00:31
# num of updates: 800
# loss: 8.64722
# eval avg reward: 4.00000
# best score: 4.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.09060
# lr 0.00008
# achieved average reward:  4.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-another_model_24-05-09-20-50-55_best.pt
# saving current model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-another_model_24-05-09-20-50-55.pt
# ============================================================
# time elapsed: 0:00:33
# num of updates: 900
# loss: 8.54219
# eval avg reward: 4.00000
# best score: 4.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.09070
# lr 0.00009
# achieved average reward:  4.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-another_model_24-05-09-20-50-55_best.pt
# saving current model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-another_model_24-05-09-20-50-55.pt
# ============================================================
# time elapsed: 0:00:36
# num of updates: 1000
# loss: 8.44279
# eval avg reward: 4.00000
# best score: 4.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.09269
# lr 0.00010
# achieved average reward:  4.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-another_model_24-05-09-20-50-55_best.pt
# saving current model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-another_model_24-05-09-20-50-55.pt
# ============================================================
# time elapsed: 0:00:43
# num of updates: 1100
# loss: 8.36135
# eval avg reward: 4.00000
# best score: 4.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.09322
# lr 0.00011
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 report = trainer.train()
#
# File ~/projects/RL-credit-assignment-experiment/algorithms/sequence_models/trainer.py:36, in Trainer.train(self)
#      34 df = []
#      35 for i_train_iter in range(self.config.max_train_iters):
# ---> 36     df_iter = self.train_iteration()
#      37     df_iter['train/iteration'] = i_train_iter
#      38     df.append(df_iter)
#
# File ~/projects/RL-credit-assignment-experiment/algorithms/sequence_models/decision_transformer/trainer.py:20, in TrainerDT.train_iteration(self)
#      18     data_iter = iter(self.traj_data_loader)
#      19     timesteps, states, actions, returns_to_go, traj_mask = next(data_iter)
# ---> 20 res = self.train_step(timesteps, states, actions, returns_to_go, traj_mask)
#      21 res['train/update_idx'] = update_idx
#      22 df.append(res)
#
# File ~/projects/RL-credit-assignment-experiment/algorithms/sequence_models/decision_transformer/trainer.py:58, in TrainerDT.train_step(self, timesteps, states, actions, returns_to_go, traj_mask)
#      55 if self.scheduler is not None:
#      56     self.scheduler.step()
# ---> 58 return {"train/loss": action_loss.detach().cpu().item()}
#
# KeyboardInterrupt:

# %%
model
# Out:
# DecisionTransformer(
#   (transformer): Sequential(
#     (0): Block(
#       (attention): MaskedCausalAttention(
#         (q_net): Linear(in_features=128, out_features=128, bias=True)
#         (k_net): Linear(in_features=128, out_features=128, bias=True)
#         (v_net): Linear(in_features=128, out_features=128, bias=True)
#         (proj_net): Linear(in_features=128, out_features=128, bias=True)
#         (att_drop): Dropout(p=0.1, inplace=False)
#         (proj_drop): Dropout(p=0.1, inplace=False)
#       )
#       (mlp): Sequential(
#         (0): Linear(in_features=128, out_features=512, bias=True)
#         (1): GELU(approximate='none')
#         (2): Linear(in_features=512, out_features=128, bias=True)
#         (3): Dropout(p=0.1, inplace=False)
#       )
#       (ln1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (ln2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     )
#     (1): Block(
#       (attention): MaskedCausalAttention(
#         (q_net): Linear(in_features=128, out_features=128, bias=True)
#         (k_net): Linear(in_features=128, out_features=128, bias=True)
#         (v_net): Linear(in_features=128, out_features=128, bias=True)
#         (proj_net): Linear(in_features=128, out_features=128, bias=True)
#         (att_drop): Dropout(p=0.1, inplace=False)
#         (proj_drop): Dropout(p=0.1, inplace=False)
#       )
#       (mlp): Sequential(
#         (0): Linear(in_features=128, out_features=512, bias=True)
#         (1): GELU(approximate='none')
#         (2): Linear(in_features=512, out_features=128, bias=True)
#         (3): Dropout(p=0.1, inplace=False)
#       )
#       (ln1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (ln2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     )
#     (2): Block(
#       (attention): MaskedCausalAttention(
#         (q_net): Linear(in_features=128, out_features=128, bias=True)
#         (k_net): Linear(in_features=128, out_features=128, bias=True)
#         (v_net): Linear(in_features=128, out_features=128, bias=True)
#         (proj_net): Linear(in_features=128, out_features=128, bias=True)
#         (att_drop): Dropout(p=0.1, inplace=False)
#         (proj_drop): Dropout(p=0.1, inplace=False)
#       )
#       (mlp): Sequential(
#         (0): Linear(in_features=128, out_features=512, bias=True)
#         (1): GELU(approximate='none')
#         (2): Linear(in_features=512, out_features=128, bias=True)
#         (3): Dropout(p=0.1, inplace=False)
#       )
#       (ln1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (ln2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (embed_ln): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (embed_timestep): Embedding(4096, 128)
#   (embed_rtg): Linear(in_features=1, out_features=128, bias=True)
#   (embed_state): Linear(in_features=10, out_features=128, bias=True)
#   (embed_action): Linear(in_features=10, out_features=128, bias=True)
#   (predict_rtg): Linear(in_features=128, out_features=1, bias=True)
#   (predict_state): Linear(in_features=128, out_features=10, bias=True)
#   (predict_action): Sequential(
#     (0): Linear(in_features=128, out_features=10, bias=True)
#     (1): Tanh()
#   )
# )

# %%
callback.plot_eval_results()

# %%
report.sort_values(by=['train/iteration', 'train/update_idx']).reset_index()['train/loss'].plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Compare with S4

# %%
from s4.dts4 import DecisionS4 # todo later move to algorithms folder

experiment_name = 'random-walk-simple-s4'

model_s4 = DecisionS4(
    state_dim=traj_dataset.state_dim(),
    act_dim=traj_dataset.action_dim(),
    h_dim=config.embed_dim,
    context_len=config.context_len,
    drop_p=config.dropout_p,
).to(device)

optimizer = torch.optim.AdamW(model_s4.parameters(), lr=config.lr, weight_decay=config.wt_decay)

scheduler = torch.optim.lr_scheduler.LambdaLR(
	optimizer,
	lambda steps: min((steps+1)/config.warmup_steps, 1)
)

loss_fn = nn.MSELoss(reduction='mean')

trainer = TrainerDT(name=experiment_name, model=model_s4,
					optimizer=optimizer, loss_fn=loss_fn,
					dataset=LimitedContextWrapper(traj_dataset, context_len=config.context_len),
					device=device, config=config, scheduler=scheduler)

callback = CustomCallback(env=env, model=model_s4,
						  optimizer=optimizer, logger=trainer.logger, device=device, traj_dataset=traj_dataset, config=config,
						  rtgs=np.linspace(config.rtg_range_check[0], config.rtg_range_check[1], 5))

trainer.register_callback(callback.callback)

print("number of parameters", sum(np.prod(param.shape) for param in model_s4.parameters()))
# Out:
# number of parameters 596373

# %%
report = trainer.train()
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# achieved average reward:  -32.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:01
# num of updates: 100
# loss: 11.98128
# eval avg reward: -32.00000
# best score: -inf
# eval_avg_ep_len 7.00000
# grad_norm 0.10803
# lr 0.00001
# achieved average reward:  -32.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:02
# num of updates: 200
# loss: 11.02888
# eval avg reward: -32.00000
# best score: -32.00000
# eval_avg_ep_len 7.00000
# grad_norm 0.06640
# lr 0.00002
# achieved average reward:  -19.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:03
# num of updates: 300
# loss: 10.08359
# eval avg reward: -19.00000
# best score: -32.00000
# eval_avg_ep_len 5.00000
# grad_norm 0.04010
# lr 0.00003
# achieved average reward:  -5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:04
# num of updates: 400
# loss: 9.55788
# eval avg reward: -5.00000
# best score: -19.00000
# eval_avg_ep_len 3.00000
# grad_norm 0.03217
# lr 0.00004
# achieved average reward:  -5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:04
# num of updates: 500
# loss: 9.26967
# eval avg reward: -5.00000
# best score: -5.00000
# eval_avg_ep_len 3.00000
# grad_norm 0.02575
# lr 0.00005
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:05
# num of updates: 600
# loss: 9.08569
# eval avg reward: 5.00000
# best score: -5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02302
# lr 0.00006
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:06
# num of updates: 700
# loss: 8.95142
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.01989
# lr 0.00007
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:07
# num of updates: 800
# loss: 8.81781
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.01872
# lr 0.00008
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:07
# num of updates: 900
# loss: 8.70376
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.01967
# lr 0.00009
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:08
# num of updates: 1000
# loss: 8.62969
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.01741
# lr 0.00010
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:09
# num of updates: 1100
# loss: 8.55702
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02304
# lr 0.00011
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:09
# num of updates: 1200
# loss: 8.51162
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.01691
# lr 0.00012
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:10
# num of updates: 1300
# loss: 8.45245
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.01749
# lr 0.00013
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:11
# num of updates: 1400
# loss: 8.41869
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.01847
# lr 0.00014
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:11
# num of updates: 1500
# loss: 8.37775
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.01742
# lr 0.00015
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:12
# num of updates: 1600
# loss: 8.33407
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02257
# lr 0.00016
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:13
# num of updates: 1700
# loss: 8.29849
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.01959
# lr 0.00017
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:13
# num of updates: 1800
# loss: 8.26748
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.01990
# lr 0.00018
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:14
# num of updates: 1900
# loss: 8.23496
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.01677
# lr 0.00019
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:15
# num of updates: 2000
# loss: 8.20817
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02070
# lr 0.00020
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:15
# num of updates: 2100
# loss: 8.18361
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02027
# lr 0.00021
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:17
# num of updates: 2200
# loss: 8.15444
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.01939
# lr 0.00022
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:17
# num of updates: 2300
# loss: 8.12711
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02162
# lr 0.00023
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:18
# num of updates: 2400
# loss: 8.10119
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02048
# lr 0.00024
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:19
# num of updates: 2500
# loss: 8.06712
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02038
# lr 0.00025
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:20
# num of updates: 2600
# loss: 8.04501
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02012
# lr 0.00026
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:21
# num of updates: 2700
# loss: 8.00839
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02014
# lr 0.00027
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:21
# num of updates: 2800
# loss: 7.97240
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.01940
# lr 0.00028
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:22
# num of updates: 2900
# loss: 7.94343
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02370
# lr 0.00029
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:23
# num of updates: 3000
# loss: 7.90321
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02476
# lr 0.00030
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:24
# num of updates: 3100
# loss: 7.86697
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.01968
# lr 0.00031
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:24
# num of updates: 3200
# loss: 7.82119
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02020
# lr 0.00032
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:25
# num of updates: 3300
# loss: 7.79184
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02120
# lr 0.00033
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:26
# num of updates: 3400
# loss: 7.73136
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02262
# lr 0.00034
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:26
# num of updates: 3500
# loss: 7.68363
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02321
# lr 0.00035
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:27
# num of updates: 3600
# loss: 7.63549
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02745
# lr 0.00036
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:28
# num of updates: 3700
# loss: 7.57650
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02425
# lr 0.00037
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:28
# num of updates: 3800
# loss: 7.51370
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02875
# lr 0.00038
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:29
# num of updates: 3900
# loss: 7.45335
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02386
# lr 0.00039
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:30
# num of updates: 4000
# loss: 7.38587
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02601
# lr 0.00040
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:30
# num of updates: 4100
# loss: 7.31774
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02888
# lr 0.00041
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:31
# num of updates: 4200
# loss: 7.25343
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03116
# lr 0.00042
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:32
# num of updates: 4300
# loss: 7.17827
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02710
# lr 0.00043
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:33
# num of updates: 4400
# loss: 7.10089
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02782
# lr 0.00044
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:33
# num of updates: 4500
# loss: 7.03504
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02683
# lr 0.00045
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:34
# num of updates: 4600
# loss: 6.94987
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02593
# lr 0.00046
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:35
# num of updates: 4700
# loss: 6.86377
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03146
# lr 0.00047
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:36
# num of updates: 4800
# loss: 6.77951
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03018
# lr 0.00048
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:37
# num of updates: 4900
# loss: 6.70756
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02873
# lr 0.00049
# saving current model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31.pt
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:38
# num of updates: 5000
# loss: 6.62193
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03093
# lr 0.00050
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:38
# num of updates: 5100
# loss: 6.54910
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02949
# lr 0.00051
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:39
# num of updates: 5200
# loss: 6.46238
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03149
# lr 0.00052
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:40
# num of updates: 5300
# loss: 6.39359
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02964
# lr 0.00053
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:41
# num of updates: 5400
# loss: 6.32430
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02867
# lr 0.00054
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:41
# num of updates: 5500
# loss: 6.23748
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03429
# lr 0.00055
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:42
# num of updates: 5600
# loss: 6.17577
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02967
# lr 0.00056
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:43
# num of updates: 5700
# loss: 6.09676
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03149
# lr 0.00057
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:43
# num of updates: 5800
# loss: 6.02532
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03699
# lr 0.00058
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:44
# num of updates: 5900
# loss: 5.97423
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03152
# lr 0.00059
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:45
# num of updates: 6000
# loss: 5.90007
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03074
# lr 0.00060
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:46
# num of updates: 6100
# loss: 5.84353
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03134
# lr 0.00061
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:46
# num of updates: 6200
# loss: 5.77872
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02956
# lr 0.00062
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:47
# num of updates: 6300
# loss: 5.73479
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03283
# lr 0.00063
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:48
# num of updates: 6400
# loss: 5.66199
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02857
# lr 0.00064
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:49
# num of updates: 6500
# loss: 5.62050
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03605
# lr 0.00065
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:50
# num of updates: 6600
# loss: 5.57171
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03056
# lr 0.00066
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:51
# num of updates: 6700
# loss: 5.50687
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03262
# lr 0.00067
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:51
# num of updates: 6800
# loss: 5.44489
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02665
# lr 0.00068
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:52
# num of updates: 6900
# loss: 5.41237
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03701
# lr 0.00069
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:53
# num of updates: 7000
# loss: 5.36718
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02903
# lr 0.00070
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:54
# num of updates: 7100
# loss: 5.32424
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03123
# lr 0.00071
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:54
# num of updates: 7200
# loss: 5.27751
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03252
# lr 0.00072
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:55
# num of updates: 7300
# loss: 5.24593
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02947
# lr 0.00073
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:56
# num of updates: 7400
# loss: 5.20629
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03498
# lr 0.00074
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:57
# num of updates: 7500
# loss: 5.15901
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.05310
# lr 0.00075
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:58
# num of updates: 7600
# loss: 5.12685
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03597
# lr 0.00076
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:58
# num of updates: 7700
# loss: 5.08247
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02660
# lr 0.00077
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:00:59
# num of updates: 7800
# loss: 5.03987
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03460
# lr 0.00078
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:00
# num of updates: 7900
# loss: 5.01885
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02984
# lr 0.00079
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:01
# num of updates: 8000
# loss: 4.98447
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.04276
# lr 0.00080
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:01
# num of updates: 8100
# loss: 4.95455
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.04029
# lr 0.00081
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:02
# num of updates: 8200
# loss: 4.92430
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03956
# lr 0.00082
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:03
# num of updates: 8300
# loss: 4.87876
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03018
# lr 0.00083
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:04
# num of updates: 8400
# loss: 4.84807
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03540
# lr 0.00084
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:04
# num of updates: 8500
# loss: 4.81083
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.04240
# lr 0.00085
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:05
# num of updates: 8600
# loss: 4.79573
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.05285
# lr 0.00086
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:06
# num of updates: 8700
# loss: 4.75907
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.04332
# lr 0.00087
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:06
# num of updates: 8800
# loss: 4.73872
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.04009
# lr 0.00088
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:07
# num of updates: 8900
# loss: 4.71090
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03503
# lr 0.00089
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:08
# num of updates: 9000
# loss: 4.67558
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03028
# lr 0.00090
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:08
# num of updates: 9100
# loss: 4.65857
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02919
# lr 0.00091
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:09
# num of updates: 9200
# loss: 4.62742
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02598
# lr 0.00092
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:10
# num of updates: 9300
# loss: 4.58980
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03372
# lr 0.00093
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:10
# num of updates: 9400
# loss: 4.57387
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.04019
# lr 0.00094
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:11
# num of updates: 9500
# loss: 4.53548
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.04468
# lr 0.00095
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:12
# num of updates: 9600
# loss: 4.52419
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02723
# lr 0.00096
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:12
# num of updates: 9700
# loss: 4.50789
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.09567
# lr 0.00097
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:13
# num of updates: 9800
# loss: 4.48305
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.04681
# lr 0.00098
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:14
# num of updates: 9900
# loss: 4.45194
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03131
# lr 0.00099
# saving current model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31.pt
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:14
# num of updates: 10000
# loss: 4.41983
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.04538
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:15
# num of updates: 10100
# loss: 4.41850
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.05004
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:16
# num of updates: 10200
# loss: 4.37491
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03834
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:17
# num of updates: 10300
# loss: 4.35809
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.04620
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:17
# num of updates: 10400
# loss: 4.33349
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.04476
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:18
# num of updates: 10500
# loss: 4.33029
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03845
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:19
# num of updates: 10600
# loss: 4.31574
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03950
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:20
# num of updates: 10700
# loss: 4.30874
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.04911
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:20
# num of updates: 10800
# loss: 4.26340
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03735
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:21
# num of updates: 10900
# loss: 4.25495
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.04655
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:22
# num of updates: 11000
# loss: 4.23889
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03277
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:23
# num of updates: 11100
# loss: 4.22174
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02444
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:24
# num of updates: 11200
# loss: 4.20695
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02236
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:24
# num of updates: 11300
# loss: 4.18527
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.06404
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:25
# num of updates: 11400
# loss: 4.17778
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02902
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:26
# num of updates: 11500
# loss: 4.16079
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02703
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:27
# num of updates: 11600
# loss: 4.15401
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03715
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:27
# num of updates: 11700
# loss: 4.13402
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.05065
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:28
# num of updates: 11800
# loss: 4.12343
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.04374
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:29
# num of updates: 11900
# loss: 4.10880
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03137
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:29
# num of updates: 12000
# loss: 4.10032
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.05919
# ...
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.04750
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:59
# num of updates: 16300
# loss: 3.74994
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03119
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:01:59
# num of updates: 16400
# loss: 3.74745
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.05771
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:00
# num of updates: 16500
# loss: 3.74800
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03806
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:01
# num of updates: 16600
# loss: 3.74090
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02871
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:02
# num of updates: 16700
# loss: 3.72176
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02609
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:03
# num of updates: 16800
# loss: 3.72432
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.06979
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:03
# num of updates: 16900
# loss: 3.72381
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02495
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:04
# num of updates: 17000
# loss: 3.70543
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.04681
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:05
# num of updates: 17100
# loss: 3.69764
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03918
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:05
# num of updates: 17200
# loss: 3.69333
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03396
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:06
# num of updates: 17300
# loss: 3.70824
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03870
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:07
# num of updates: 17400
# loss: 3.69642
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.04438
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:08
# num of updates: 17500
# loss: 3.67919
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.09842
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:08
# num of updates: 17600
# loss: 3.67639
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.04208
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:09
# num of updates: 17700
# loss: 3.67003
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.04952
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:10
# num of updates: 17800
# loss: 3.66900
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03587
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:10
# num of updates: 17900
# loss: 3.66557
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.04056
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:11
# num of updates: 18000
# loss: 3.66213
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.08665
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:12
# num of updates: 18100
# loss: 3.66038
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.04381
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:12
# num of updates: 18200
# loss: 3.64301
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03186
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:13
# num of updates: 18300
# loss: 3.65173
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02226
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:14
# num of updates: 18400
# loss: 3.64672
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02634
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:15
# num of updates: 18500
# loss: 3.63344
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03215
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:15
# num of updates: 18600
# loss: 3.62830
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.04085
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:16
# num of updates: 18700
# loss: 3.63824
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.02915
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:17
# num of updates: 18800
# loss: 3.64126
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.06727
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:18
# num of updates: 18900
# loss: 3.61234
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03084
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:19
# num of updates: 19000
# loss: 3.62057
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.06017
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:20
# num of updates: 19100
# loss: 3.61197
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.10642
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:21
# num of updates: 19200
# loss: 3.62936
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03551
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:21
# num of updates: 19300
# loss: 3.62319
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03501
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:22
# num of updates: 19400
# loss: 3.60676
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03232
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:23
# num of updates: 19500
# loss: 3.60467
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03482
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:23
# num of updates: 19600
# loss: 3.60475
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03477
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:24
# num of updates: 19700
# loss: 3.60140
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03723
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:25
# num of updates: 19800
# loss: 3.59060
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.04386
# lr 0.00100
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:25
# num of updates: 19900
# loss: 3.57413
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03692
# lr 0.00100
# saving current model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31.pt
# achieved average reward:  5.0
# saving max score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# ============================================================
# time elapsed: 0:02:26
# num of updates: 20000
# loss: 3.58398
# eval avg reward: 5.00000
# best score: 5.00000
# eval_avg_ep_len 1.00000
# grad_norm 0.03769
# lr 0.00100
# ============================================================
# finished training!
# ============================================================
# started training at: 24-05-10-13-12-31
# finished training at: 24-05-10-13-14-58
# total training time: 0:02:27
# best score: 5.00000
# saved max d4rl score model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31_best.pt
# saved last updated model at: /home/shayan/projects/RL-credit-assignment-experiment/logs/dt_runs/dt_random-walk-simple-s4_model_24-05-10-13-12-31.pt
# ============================================================

# %%
# plot losses

report.sort_values(by=['train/iteration', 'train/update_idx']).reset_index()['train/loss'].plot()
# Out:
# <Axes: >

# %%
report['train/loss']
# Out:
# 0     0.121003
# 1     0.122556
# 2     0.122416
# 3     0.123274
# 4     0.120859
#         ...
# 95    0.034880
# 96    0.035948
# 97    0.036265
# 98    0.036606
# 99    0.033459
# Name: train/loss, Length: 20000, dtype: float64

# %%
# how was the model learning while training?
callback.plot_eval_results()

# %%
# main plot. command vs return

from tqdm.notebook import tqdm

rtg_command = np.linspace(config.rtg_range_check[0], config.rtg_range_check[1], 30)

rtg_result = []

for rtg in tqdm(rtg_command):
	res = evaluate_on_env(
		model=model_s4,
		traj_dataset=traj_dataset,
		device=device,
		context_len=config.context_len,
		env=env,
		rtg_target=rtg,
		num_eval_ep=config.num_eval_ep
	)
	rtg_result.append(res['eval/avg_reward'])

plt.plot(rtg_command, rtg_result, 'r')
plt.plot(rtg_command, rtg_command, 'b')
plt.xlabel("rtg_command")
plt.ylabel("rtg_result")


########################## specific to RandomWalk
import networkx as nx

shortest_path = nx.shortest_path(env.G, env.starting_vertex, env.ending_vertex, weight='weight')
best_score = env.reach_the_goal_reward - sum(env.G[a][b]['weight'] for a, b in zip(shortest_path[:-1], shortest_path[1:]))

plt.hlines(best_score, config.rtg_range_check[0], config.rtg_range_check[1])
########################## specific to RandomWalk

plt.legend(["achieved", "commanded", "best"])
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
